# %%
## The goal of this notebook is to analyze the tweets from the Sept. 26 and Oct. 9 2016 US Presidential Debates

## use BOTH models
## maybe average them?

# %%
## import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import random
import os
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import string
from collections import Counter
import scipy.sparse
from prettytable import PrettyTable
import gc
gc.collect()

## display the plots inline
# %matplotlib inline

## load the processed test-set tweets
df_test = pd.read_pickle('../tweet_data/test_data/debate_data_processed.pkl')

## if the small flag is True, load quantities associated with a very small fraction of the total data
small = False
if small:
  frac = 0.01
  df_test = df_test.iloc[random.sample(range(0, len(df_test)), int(math.floor(frac*len(df_test))))]
  df_test = df_test.reset_index(drop=True)
  path = '../model_parameters/small_'
else:
  path = '../model_parameters/'
  
print 'test data set size:', len(df_test)

## load the MaxEnt models parameters
## start with the sparse feature matrix
def load_sparse_csr(filename):
    loader = np.load(filename)
    return scipy.sparse.csr_matrix((  loader['data'], loader['indices'], loader['indptr']),
                         shape = loader['shape'])
feature = load_sparse_csr(path + 'feature.npz')
beta_list = np.load(path + 'beta_list.npy')
lambda_list = np.load(path + 'lambda_list.npy')
LL_cv = np.load(path + 'LL_cv.npy')
## load the Naive Bayes models parameters
words_unique = list(np.load(path + 'words_unique.npy'))
max_rank = len(words_unique)
prior_neg = np.float(np.load(path + 'prior_neg.npy'))
prior_neutral = np.float(np.load(path + 'prior_neutral.npy'))
prior_pos = np.float(np.load(path + 'prior_pos.npy'))
ranks_tot = list(np.load(path + 'ranks_tot.npy'))
ranks_tot_neg = list(np.load(path + 'ranks_tot_neg.npy'))
ranks_tot_neutral = list(np.load(path + 'ranks_tot_neutral.npy'))
ranks_tot_pos = list(np.load(path + 'ranks_tot_pos.npy'))
# Out:
# test data set size: 131646

# %%
## for the MaxEnt model, find the value of the parameters corresponding to beta*
jbest = [ LL_cv[j][-1] for j in range(len(LL_cv))].index(max([ LL_cv[j][-1] for j in range(len(LL_cv))]))
lambda_neg = lambda_list[jbest][0]
lambda_neutral = lambda_list[jbest][1]
lambda_pos = lambda_list[jbest][2]

# %%
## Work out the predictions for both models

## convert word list to word rank list
def word_to_rank(x):
  return sorted([ words_unique.index(w) for w in x if w in words_unique])

## create the sparse feature matrices
def feature_matrix(df):
  feature = scipy.sparse.lil_matrix((len(df), max_rank))
  for j in range(len(df)):
    for i in range(len(df['word_ranks'].iloc[j])):
      feature[j, df['word_ranks'].iloc[j][i]] += 1.0/(len(df['word_ranks'].iloc[j]))
  return scipy.sparse.csr_matrix(feature) ## convert into csr matrix

## prediction accuracy
def ME_predictions(df, feature, lambda_neg, lambda_neutral, lambda_pos):
  flambda_neg = feature.dot(lambda_neg)
  flambda_neutral = feature.dot(lambda_neutral)
  flambda_pos = feature.dot(lambda_pos)
  boltz_neg = np.squeeze(np.asarray(np.exp(flambda_neg)))
  boltz_neutral = np.squeeze(np.asarray(np.exp(flambda_neutral)))
  boltz_pos = np.squeeze(np.asarray(np.exp(flambda_pos)))
  predict = []
  for i in range(len(df)):
    p_neg = boltz_neg[i]
    p_neutral = boltz_neutral[i]
    p_pos = boltz_pos[i]
    predict.append(-1 + [p_neg, p_neutral, p_pos].index(max([p_neg, p_neutral, p_pos])))
  return predict

## conditional probabilities of word given class (with Laplace smoothing parameter alpha)
alpha = 1 # Laplace smoothing parameter
def p_rank_given_neg(rank):
  return float(counter_neg[rank] + alpha)/(len(ranks_tot_neg) + alpha*len(ranks_tot))
def p_rank_given_neutral(rank):
  return float(counter_neutral[rank] + alpha)/(len(ranks_tot_neutral) + alpha*len(ranks_tot))
def p_rank_given_pos(rank):
  return float(counter_pos[rank] + alpha)/(len(ranks_tot_pos) + alpha*len(ranks_tot))

## NB prediction
def NB_predict(rank_list):
  p_neg = math.log(prior_neg) + sum([math.log(p_rank_given_neg(i)) for i in rank_list])
  p_neutral = math.log(prior_neutral) + sum([math.log(p_rank_given_neutral(i)) for i in rank_list])
  p_pos = math.log(prior_pos) + sum([math.log(p_rank_given_pos(i)) for i in rank_list])
  return -1 + [p_neg, p_neutral, p_pos].index(max([p_neg, p_neutral, p_pos]))

counter = Counter(ranks_tot)
counter_neg = Counter(ranks_tot_neg)
counter_neutral = Counter(ranks_tot_neutral)
counter_pos = Counter(ranks_tot_pos)
df_test['word_ranks'] = df_test['words'].map(word_to_rank)

## NB predictions
df_test['NB predictions'] = df_test['word_ranks'].map(NB_predict)

## ME predictions
feature_test = feature_matrix(df_test)
testpred = ME_predictions(df_test, feature_test, lambda_neg, lambda_neutral, lambda_pos)
df_test['ME predictions'] = testpred

# %%
## Naive Bayes
print 'Sept. 26 Debate'
print 'sentiment:', 1.0*sum(df_test[df_test['event date']=='sept26']['NB predictions'])/len(df_test[df_test['event date']=='sept26'])
print ' positive:', 1.0*sum(df_test[df_test['event date']=='sept26']['NB predictions']==1)/len(df_test[df_test['event date']=='sept26'])
print ' neutral:', 1.0*sum(df_test[df_test['event date']=='sept26']['NB predictions']==0)/len(df_test[df_test['event date']=='sept26'])
print ' negative:', 1.0*sum(df_test[df_test['event date']=='sept26']['NB predictions']==-1)/len(df_test[df_test['event date']=='sept26'])

print 'Oct. 9 Debate'
print 'sentiment:', 1.0*sum(df_test[df_test['event date']=='oct09']['NB predictions'])/len(df_test[df_test['event date']=='oct09'])
print ' positive:', 1.0*sum(df_test[df_test['event date']=='oct09']['NB predictions']==1)/len(df_test[df_test['event date']=='oct09'])
print ' neutral:', 1.0*sum(df_test[df_test['event date']=='oct09']['NB predictions']==0)/len(df_test[df_test['event date']=='oct09'])
print ' negative:', 1.0*sum(df_test[df_test['event date']=='oct09']['NB predictions']==-1)/len(df_test[df_test['event date']=='oct09'])

print 'Oct. 19 Debate'
print 'sentiment:', 1.0*sum(df_test[df_test['event date']=='oct19']['NB predictions'])/len(df_test[df_test['event date']=='oct19'])
print ' positive:', 1.0*sum(df_test[df_test['event date']=='oct19']['NB predictions']==1)/len(df_test[df_test['event date']=='oct19'])
print ' neutral:', 1.0*sum(df_test[df_test['event date']=='oct19']['NB predictions']==0)/len(df_test[df_test['event date']=='oct19'])
print ' negative:', 1.0*sum(df_test[df_test['event date']=='oct19']['NB predictions']==-1)/len(df_test[df_test['event date']=='oct19'])
# Out:
# Sept. 26 Debate
# sentiment: 0.0676679182311
#  positive: 0.115581977472
#  neutral: 0.836503963287
#  negative: 0.0479140592407
# Oct. 9 Debate
# sentiment: 0.0613735173695
#  positive: 0.106960449116
#  neutral: 0.847452619138
#  negative: 0.0455869317462
# Oct. 19 Debate
# sentiment: 0.0123609734611
#  positive: 0.0625206475058
#  neutral: 0.88731967845
#  negative: 0.0501596740447

# %%
## drop some initial tweets so that the data collection starts precisely on Sept. 24 UTC time
i = 0
cond = True
while cond:
  i += 1
  if df_test['created_at'].iloc[i][0:10] == 'Sat Sep 24':
    cond = False
df_test = df_test.iloc[i-1:]
df_test = df_test.reset_index(drop=True)

# %%
## create continuous time label
time_list = []
for i in range(len(df_test)):
  month = df_test['created_at'].iloc[i][4:7]
  day = int(df_test['created_at'].iloc[i][8:10])
  hour = int(df_test['created_at'].iloc[i][11:13])
  minute = int(df_test['created_at'].iloc[i][14:16])
  second = int(df_test['created_at'].iloc[i][17:19])
  sept_to_oct_shift = ((30*24 + 23)*60 + 59)*60 + 59
  if i == 0:
    time0 = ((day*24 + hour)*60 + minute)*60 + second
  if month == 'Sep':
    time = ((day*24 + hour)*60 + minute)*60 + second - time0
    time_list.append(1.0*time/(60*60*24))
  if month == 'Oct':
    time = ((day*24 + hour)*60 + minute)*60 + second + (sept_to_oct_shift - time0)
    time_list.append(1.0*time/(60*60*24))

df_test['time'] = time_list

# %%
## examine tweets that mention just Clinton or just Trump
HRCwords = [u'hrc', u'hillary', u'clinton', u'hashtagtokenhillaryclinton', u'hashtagtokenhillary']
DJTwords = [u'donald', u'trump', u'hashtagtokendonaldtrump', u'hashtagtokentrumppence']

def in_list(list_to_search, terms_to_search, terms_to_exclude):
    pos_results = [item for item in list_to_search if item in terms_to_search]
    neg_results = [item for item in list_to_search if item in terms_to_exclude]
    if len(pos_results) > 0 and len(neg_results) == 0:
        return True
    else:
        return False
      
df_test['Trump'] = df_test['words'].apply(lambda x: in_list(x, DJTwords, HRCwords))
df_test['Clinton'] = df_test['words'].apply(lambda x: in_list(x, HRCwords, DJTwords))

# %%
## Naive Bayes Predictions
model_predictions = 'NB predictions'

## moving average of the sentiment values  
def yvalue(df, win):
  return list(np.asarray(df[model_predictions].rolling(window=win,center=False).mean()))
window = 1000

mov_avg_sept26 = yvalue(df_test[df_test['event date']=='sept26'], window)
mov_avg_oct09 = yvalue(df_test[df_test['event date']=='oct09'], window)
mov_avg_oct19 = yvalue(df_test[df_test['event date']=='oct19'], window)
mov_avg = mov_avg_sept26 + mov_avg_oct09 + mov_avg_oct19
df_test['moving avg'] = mov_avg

# %%
## look at the average sentiment for each debate
fig = plt.figure(figsize=(12, 5))
ymin = -0.1
ymax = 0.2
## subplot 1
sub1 = fig.add_subplot(121)
sub1.set_title('Sept. 26 Debate', fontsize=20)
xval = list(df_test[df_test['event date'] == 'sept26']['time'].iloc[window-1:])
yval = list(df_test[df_test['event date'] == 'sept26']['moving avg'].iloc[window-1:])
sub1.plot(xval, yval, c='black')
sub1.set_xlim([xval[0], xval[-1]])
sub1.set_ylim([ymin, ymax])
sub1.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub1.set_ylabel('avg. sentiment', fontsize=20)
sub1.plot(xval, np.zeros(len(xval)), 'r--')
sub1.axvline(3 + 2.0/24, color='k', linestyle=':')
## subplot 2
sub2 = fig.add_subplot(122)
sub2.set_title('Oct. 09 Debate', fontsize=20)
xval = list(df_test[df_test['event date'] == 'oct09']['time'].iloc[window-1:])
yval = list(df_test[df_test['event date'] == 'oct09']['moving avg'].iloc[window-1:])
sub2.plot(xval, yval, c='black')
sub2.set_xlim([xval[0], xval[-1]])
sub2.set_ylim([ymin, ymax])
sub2.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub2.set_ylabel('avg. sentiment', fontsize=20)
sub2.plot(xval, np.zeros(len(xval)), 'r--')
sub2.axvline(17.1, color='k', linestyle=':')
## finish up
plt.tight_layout()
plt.savefig('figures/NB_Debates_1and2_AvgSent.png')
plt.show()

# %%
## look at the average sentiment for each debate
fig = plt.figure(figsize=(17, 5))
ymin = -0.06
ymax = 0.1

## use a smaller window for the first two debates
window = 1000
time_sept26_Trump = list(df_test[(df_test['event date']=='sept26') & (df_test['Trump'] == True)]['time'])
time_oct09_Trump = list(df_test[(df_test['event date']=='oct09') & (df_test['Trump'] == True)]['time'])
mov_avg_sept26_Trump = yvalue(df_test[(df_test['event date']=='sept26') & (df_test['Trump'] == True)], window)
mov_avg_oct09_Trump = yvalue(df_test[(df_test['event date']=='oct09') & (df_test['Trump'] == True)], window)

time_sept26_Clinton = list(df_test[(df_test['event date']=='sept26') & (df_test['Clinton'] == True)]['time'])
time_oct09_Clinton = list(df_test[(df_test['event date']=='oct09') & (df_test['Clinton'] == True)]['time'])
mov_avg_sept26_Clinton = yvalue(df_test[(df_test['event date']=='sept26') & (df_test['Clinton'] == True)], window)
mov_avg_oct09_Clinton = yvalue(df_test[(df_test['event date']=='oct09') & (df_test['Clinton'] == True)], window)

## subplot 1
sub1 = fig.add_subplot(131)
sub1.set_title('Sept. 26 Debate', fontsize=20)
sub1.plot(time_sept26_Trump[window-1:], mov_avg_sept26_Trump[window-1:], c='red')
sub1.plot(time_sept26_Clinton[window-1:], mov_avg_sept26_Clinton[window-1:], c='blue')
sub1.set_xlim([ max(time_sept26_Clinton[window-1], time_sept26_Trump[window-1]), \
               min(time_sept26_Clinton[-1], time_sept26_Trump[-1])])
sub1.set_ylim([ymin, ymax])
sub1.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub1.set_ylabel('avg. sentiment', fontsize=20)
sub1.axhline(0, color='black', linestyle='--')
sub1.axvline(3 + 2.0/24, color='k', linestyle=':')

## subplot 2
sub2 = fig.add_subplot(132)
sub2.set_title('Oct. 09 Debate', fontsize=20)
sub2.plot(time_oct09_Trump[window-1:], mov_avg_oct09_Trump[window-1:], c='red')
sub2.plot(time_oct09_Clinton[window-1:], mov_avg_oct09_Clinton[window-1:], c='blue')
sub2.set_xlim([ max(time_oct09_Clinton[window-1], time_oct09_Trump[window-1]), \
               min(time_oct09_Clinton[-1], time_oct09_Trump[-1])])
sub2.set_ylim([ymin, ymax])
sub2.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub2.set_ylabel('avg. sentiment', fontsize=20)
sub2.axhline(0, color='black', linestyle='--')
sub2.axvline(17.1, color='k', linestyle=':')

## use a larger window for 3rd debate
window = 1500
time_oct19_Trump = list(df_test[(df_test['event date']=='oct19') & df_test['Trump']]['time'])
mov_avg_oct19_Trump = yvalue(df_test[(df_test['event date']=='oct19') & df_test['Trump']], window)
time_oct19_Clinton = list(df_test[(df_test['event date']=='oct19') & df_test['Clinton']]['time'])
mov_avg_oct19_Clinton = yvalue(df_test[(df_test['event date']=='oct19') & df_test['Clinton']], window)

## subplot 3
sub3 = fig.add_subplot(133)
sub3.set_title('Oct. 19 Debate', fontsize=20)
sub3.plot(time_oct19_Trump[window-1:], mov_avg_oct19_Trump[window-1:], c='red')
sub3.plot(time_oct19_Clinton[window-1:], mov_avg_oct19_Clinton[window-1:], c='blue')
sub3.set_xlim([ max(time_oct19_Clinton[window-1], time_oct19_Trump[window-1]), \
               min(time_oct19_Clinton[-1], time_oct19_Trump[-1])])
sub3.set_ylim([ymin, ymax])
sub3.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub3.set_ylabel('avg. sentiment', fontsize=20)
sub3.axhline(0, color='black', linestyle='--')
sub3.axvline(27.1, color='k', linestyle=':')

## finish up
plt.tight_layout()
plt.savefig('figures/NB_Debates_candidates_AvgSent.png')
plt.show()

# %%
## Maximum Entropy Predictions
model_predictions = 'ME predictions'

## moving average of the sentiment values  
def yvalue(df, win):
  return list(np.asarray(df[model_predictions].rolling(window=win,center=False).mean()))
window = 1000

mov_avg_sept26 = yvalue(df_test[df_test['event date']=='sept26'], window)
mov_avg_oct09 = yvalue(df_test[df_test['event date']=='oct09'], window)
mov_avg_oct19 = yvalue(df_test[df_test['event date']=='oct19'], window)
mov_avg = mov_avg_sept26 + mov_avg_oct09 + mov_avg_oct19
df_test['moving avg'] = mov_avg

# %%
## look at the average sentiment for each debate
fig = plt.figure(figsize=(12, 5))
ymin = -0.1
ymax = 0.7
## subplot 1
sub1 = fig.add_subplot(121)
sub1.set_title('Sept. 26 Debate', fontsize=20)
xval = list(df_test[df_test['event date'] == 'sept26']['time'].iloc[window-1:])
yval = list(df_test[df_test['event date'] == 'sept26']['moving avg'].iloc[window-1:])
sub1.plot(xval, yval, c='black')
sub1.set_xlim([xval[0], xval[-1]])
sub1.set_ylim([ymin, ymax])
sub1.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub1.set_ylabel('avg. sentiment', fontsize=20)
sub1.plot(xval, np.zeros(len(xval)), 'r--')
sub1.axvline(3 + 2.0/24, color='k', linestyle=':')
## subplot 2
sub2 = fig.add_subplot(122)
sub2.set_title('Oct. 09 Debate', fontsize=20)
xval = list(df_test[df_test['event date'] == 'oct09']['time'].iloc[window-1:])
yval = list(df_test[df_test['event date'] == 'oct09']['moving avg'].iloc[window-1:])
sub2.plot(xval, yval, c='black')
sub2.set_xlim([xval[0], xval[-1]])
sub2.set_ylim([ymin, ymax])
sub2.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub2.set_ylabel('avg. sentiment', fontsize=20)
sub2.plot(xval, np.zeros(len(xval)), 'r--')
sub2.axvline(17.1, color='k', linestyle=':')
## finish up
plt.tight_layout()
plt.savefig('figures/ME_Debates_1and2_AvgSent.png')
plt.show()

# %%
## look at the average sentiment for each debate
fig = plt.figure(figsize=(17, 5))
ymin = -0.05
ymax = 0.3

## use a smaller window for the first two debates
window = 1000
time_sept26_Trump = list(df_test[(df_test['event date']=='sept26') & (df_test['Trump'] == True)]['time'])
time_oct09_Trump = list(df_test[(df_test['event date']=='oct09') & (df_test['Trump'] == True)]['time'])
mov_avg_sept26_Trump = yvalue(df_test[(df_test['event date']=='sept26') & (df_test['Trump'] == True)], window)
mov_avg_oct09_Trump = yvalue(df_test[(df_test['event date']=='oct09') & (df_test['Trump'] == True)], window)

time_sept26_Clinton = list(df_test[(df_test['event date']=='sept26') & (df_test['Clinton'] == True)]['time'])
time_oct09_Clinton = list(df_test[(df_test['event date']=='oct09') & (df_test['Clinton'] == True)]['time'])
mov_avg_sept26_Clinton = yvalue(df_test[(df_test['event date']=='sept26') & (df_test['Clinton'] == True)], window)
mov_avg_oct09_Clinton = yvalue(df_test[(df_test['event date']=='oct09') & (df_test['Clinton'] == True)], window)

## subplot 1
sub1 = fig.add_subplot(131)
sub1.set_title('Sept. 26 Debate', fontsize=20)
sub1.plot(time_sept26_Trump[window-1:], mov_avg_sept26_Trump[window-1:], c='red')
sub1.plot(time_sept26_Clinton[window-1:], mov_avg_sept26_Clinton[window-1:], c='blue')
sub1.set_xlim([ max(time_sept26_Clinton[window-1], time_sept26_Trump[window-1]), \
               min(time_sept26_Clinton[-1], time_sept26_Trump[-1])])
sub1.set_ylim([ymin, ymax])
sub1.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub1.set_ylabel('avg. sentiment', fontsize=20)
sub1.axhline(0, color='black', linestyle='--')
sub1.axvline(3 + 2.0/24, color='k', linestyle=':')

## subplot 2
sub2 = fig.add_subplot(132)
sub2.set_title('Oct. 09 Debate', fontsize=20)
sub2.plot(time_oct09_Trump[window-1:], mov_avg_oct09_Trump[window-1:], c='red')
sub2.plot(time_oct09_Clinton[window-1:], mov_avg_oct09_Clinton[window-1:], c='blue')
sub2.set_xlim([ max(time_oct09_Clinton[window-1], time_oct09_Trump[window-1]), \
               min(time_oct09_Clinton[-1], time_oct09_Trump[-1])])
sub2.set_ylim([ymin, ymax])
sub2.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub2.set_ylabel('avg. sentiment', fontsize=20)
sub2.axhline(0, color='black', linestyle='--')
sub2.axvline(17.1, color='k', linestyle=':')

## use a larger window for 3rd debate
window = 1500
time_oct19_Trump = list(df_test[(df_test['event date']=='oct19') & df_test['Trump']]['time'])
mov_avg_oct19_Trump = yvalue(df_test[(df_test['event date']=='oct19') & df_test['Trump']], window)
time_oct19_Clinton = list(df_test[(df_test['event date']=='oct19') & df_test['Clinton']]['time'])
mov_avg_oct19_Clinton = yvalue(df_test[(df_test['event date']=='oct19') & df_test['Clinton']], window)

## subplot 3
sub3 = fig.add_subplot(133)
sub3.set_title('Oct. 19 Debate', fontsize=20)
sub3.plot(time_oct19_Trump[window-1:], mov_avg_oct19_Trump[window-1:], c='red')
sub3.plot(time_oct19_Clinton[window-1:], mov_avg_oct19_Clinton[window-1:], c='blue')
sub3.set_xlim([ max(time_oct19_Clinton[window-1], time_oct19_Trump[window-1]), \
               min(time_oct19_Clinton[-1], time_oct19_Trump[-1])])
sub3.set_ylim([ymin, ymax])
sub3.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub3.set_ylabel('avg. sentiment', fontsize=20)
sub3.axhline(0, color='black', linestyle='--')
sub3.axvline(27.1, color='k', linestyle=':')

## finish up
plt.tight_layout()
plt.savefig('figures/ME_Debates_candidates_AvgSent.png')
plt.show()

# %%
## Average of both models

## moving average of the sentiment values  
def yvalue(df, win):
  return list(np.asarray((0.5*(df['ME predictions'] + df['NB predictions'])).rolling(window=win,center=False).mean()))
window = 1000

mov_avg_sept26 = yvalue(df_test[df_test['event date']=='sept26'], window)
mov_avg_oct09 = yvalue(df_test[df_test['event date']=='oct09'], window)
mov_avg_oct19 = yvalue(df_test[df_test['event date']=='oct19'], window)
mov_avg = mov_avg_sept26 + mov_avg_oct09 + mov_avg_oct19
df_test['moving avg'] = mov_avg

# %%
## look at the average sentiment for each debate
fig = plt.figure(figsize=(12, 5))
ymin = -0.1
ymax = 0.35
## subplot 1
sub1 = fig.add_subplot(121)
sub1.set_title('Sept. 26 Debate', fontsize=20)
xval = list(df_test[df_test['event date'] == 'sept26']['time'].iloc[window-1:])
yval = list(df_test[df_test['event date'] == 'sept26']['moving avg'].iloc[window-1:])
sub1.plot(xval, yval, c='black')
sub1.set_xlim([xval[0], xval[-1]])
sub1.set_ylim([ymin, ymax])
sub1.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub1.set_ylabel('avg. sentiment', fontsize=20)
sub1.plot(xval, np.zeros(len(xval)), 'r--')
sub1.axvline(3 + 2.0/24, color='k', linestyle=':')
## subplot 2
sub2 = fig.add_subplot(122)
sub2.set_title('Oct. 09 Debate', fontsize=20)
xval = list(df_test[df_test['event date'] == 'oct09']['time'].iloc[window-1:])
yval = list(df_test[df_test['event date'] == 'oct09']['moving avg'].iloc[window-1:])
sub2.plot(xval, yval, c='black')
sub2.set_xlim([xval[0], xval[-1]])
sub2.set_ylim([ymin, ymax])
sub2.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub2.set_ylabel('avg. sentiment', fontsize=20)
sub2.plot(xval, np.zeros(len(xval)), 'r--')
sub2.axvline(17.1, color='k', linestyle=':')
## finish up
plt.tight_layout()
plt.savefig('figures/BOTH_Debates_1and2_AvgSent.png')
plt.show()

# %%
## look at the average sentiment for each debate
fig = plt.figure(figsize=(17, 5))
ymin = -0.05
ymax = 0.15

## use a smaller window for the first two debates
window = 1000
time_sept26_Trump = list(df_test[(df_test['event date']=='sept26') & (df_test['Trump'] == True)]['time'])
time_oct09_Trump = list(df_test[(df_test['event date']=='oct09') & (df_test['Trump'] == True)]['time'])
mov_avg_sept26_Trump = yvalue(df_test[(df_test['event date']=='sept26') & (df_test['Trump'] == True)], window)
mov_avg_oct09_Trump = yvalue(df_test[(df_test['event date']=='oct09') & (df_test['Trump'] == True)], window)

time_sept26_Clinton = list(df_test[(df_test['event date']=='sept26') & (df_test['Clinton'] == True)]['time'])
time_oct09_Clinton = list(df_test[(df_test['event date']=='oct09') & (df_test['Clinton'] == True)]['time'])
mov_avg_sept26_Clinton = yvalue(df_test[(df_test['event date']=='sept26') & (df_test['Clinton'] == True)], window)
mov_avg_oct09_Clinton = yvalue(df_test[(df_test['event date']=='oct09') & (df_test['Clinton'] == True)], window)

## subplot 1
sub1 = fig.add_subplot(131)
sub1.set_title('Sept. 26 Debate', fontsize=20)
sub1.plot(time_sept26_Trump[window-1:], mov_avg_sept26_Trump[window-1:], c='red')
sub1.plot(time_sept26_Clinton[window-1:], mov_avg_sept26_Clinton[window-1:], c='blue')
sub1.set_xlim([ max(time_sept26_Clinton[window-1], time_sept26_Trump[window-1]), \
               min(time_sept26_Clinton[-1], time_sept26_Trump[-1])])
sub1.set_ylim([ymin, ymax])
sub1.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub1.set_ylabel('avg. sentiment', fontsize=20)
sub1.axhline(0, color='black', linestyle='--')
sub1.axvline(3 + 1.0/24, color='k', linestyle=':')

## subplot 2
sub2 = fig.add_subplot(132)
sub2.set_title('Oct. 09 Debate', fontsize=20)
sub2.plot(time_oct09_Trump[window-1:], mov_avg_oct09_Trump[window-1:], c='red')
sub2.plot(time_oct09_Clinton[window-1:], mov_avg_oct09_Clinton[window-1:], c='blue')
sub2.set_xlim([ max(time_oct09_Clinton[window-1], time_oct09_Trump[window-1]), \
               min(time_oct09_Clinton[-1], time_oct09_Trump[-1])])
sub2.set_ylim([ymin, ymax])
sub2.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub2.set_ylabel('avg. sentiment', fontsize=20)
sub2.axhline(0, color='black', linestyle='--')
sub2.axvline(17 + 1.0/24, color='k', linestyle=':')

## use a larger window for 3rd debate
window = 1500
time_oct19_Trump = list(df_test[(df_test['event date']=='oct19') & df_test['Trump']]['time'])
mov_avg_oct19_Trump = yvalue(df_test[(df_test['event date']=='oct19') & df_test['Trump']], window)
time_oct19_Clinton = list(df_test[(df_test['event date']=='oct19') & df_test['Clinton']]['time'])
mov_avg_oct19_Clinton = yvalue(df_test[(df_test['event date']=='oct19') & df_test['Clinton']], window)

## subplot 3
sub3 = fig.add_subplot(133)
sub3.set_title('Oct. 19 Debate', fontsize=20)
sub3.plot(time_oct19_Trump[window-1:], mov_avg_oct19_Trump[window-1:], c='red')
sub3.plot(time_oct19_Clinton[window-1:], mov_avg_oct19_Clinton[window-1:], c='blue')
sub3.set_xlim([ max(time_oct19_Clinton[window-1], time_oct19_Trump[window-1]), \
               min(time_oct19_Clinton[-1], time_oct19_Trump[-1])])
sub3.set_ylim([ymin, ymax])
sub3.set_xlabel('days since Sept. 24 (UTC time)', fontsize=20)
sub3.set_ylabel('avg. sentiment', fontsize=20)
sub3.axhline(0, color='black', linestyle='--')
sub3.axvline(27 + 2.0/24, color='k', linestyle=':')

## finish up
plt.tight_layout()
plt.savefig('figures/BOTH_Debates_candidates_AvgSent.png')
plt.show()
